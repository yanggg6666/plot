# %% [markdown]
# <a href="https://colab.research.google.com/github/yanggg6666/plot/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.show()

# %%
plt.plot([0.1, 0.2, 0.3, 0.4], [1, 2, 3, 4])

# %%
x=[1,4,9,16,25]

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 16, 81, 256, 625]

# %%
plt.plot(y)

# %%
# !pip install finlab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.1 MB/s eta 0:00:00
# ...
